# %%
# visualize_reviews.py

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'processed-reviewsv2.csv'
df = pd.read_csv(file_path)

# Display basic info
print("Dataset Summary:")
print(df.info())
print("\nFirst 5 rows:")
print(df.head())

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())

# Visualization 1: Distribution of Review Ratings (if ratings exist)
if 'rating' in df.columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x='rating', palette='viridis')
    plt.title("Distribution of Review Ratings")
    plt.xlabel("Rating")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.savefig("rating_distribution.png")
    plt.show()

# Visualization 2: Review Length Distribution
if 'review' in df.columns:
    df['review_length'] = df['review'].apply(len)
    plt.figure(figsize=(10, 5))
    sns.histplot(df['review_length'], bins=30, kde=True)
    plt.title("Review Length Distribution")
    plt.xlabel("Length of Review (characters)")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.savefig("review_length_distribution.png")
    plt.show()

# Word Cloud (optional, if 'review' column exists)
try:
    from wordcloud import WordCloud

    if 'review' in df.columns:
        all_text = " ".join(df['review'].dropna())
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)
        plt.figure(figsize=(10, 6))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title("Word Cloud of Reviews")
        plt.tight_layout()
        plt.savefig("wordcloud.png")
        plt.show()
except ImportError:
    print("wordcloud package not installed. Skipping word cloud generation.")

print("Visualizations completed.")
# Out:
# Dataset Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   username               360 non-null    object
#  1   Past Action            360 non-null    object
#  2   Time                   360 non-null    object
#  3   Review                 360 non-null    object
#  4   lowercase              360 non-null    object
#  5   no_urls                360 non-null    object
#  6   no_html                360 non-null    object
#  7   no_emojis              360 non-null    object
#  8   slang_replaced         360 non-null    object
#  9   contractions_replaced  360 non-null    object
#  10  no_punctuation         360 non-null    object
#  11  no_numbers             360 non-null    object
#  12  spelling_corrected     360 non-null    object
#  13  no_stopwords           360 non-null    object
#  14  lemmatized             360 non-null    object
#  15  tokenized              360 non-null    object
#  16  processed_review       360 non-null    object
# dtypes: object(17)
# memory usage: 47.9+ KB
# None
#
# First 5 rows:
#               username                               Past Action  \
# 0  Gayathiri Sivakumar                      3 reviews · 5 photos
# 1           Azam Kamal  Local Guide · 205 reviews · 1,571 photos
# 2        Malihah Yusof      Local Guide · 30 reviews · 71 photos
# 3   Nurul Azida (Zida)      Local Guide · 16 reviews · 58 photos
# 4       Najihah Pazaer       Local Guide · 5 reviews · 19 photos
#
#            Time                                             Review  \
# 0  2 months ago  I recently visited Suka Desert and tried a var...
# 1  2 months ago  My review is simple because I love chocolate. ...
# 2  3 months ago  Not sure why people are so hype about this. Th...
# 3  4 months ago  Love it! Cake in bowl definitely so delicious ...
# 4  2 months ago  The queue always long, tapi laju! So u dont ha...
#
#                                            lowercase  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so u dont ha...
#
#                                              no_urls  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so u dont ha...
#
#                                              no_html  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so u dont ha...
#
#                                            no_emojis  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so u dont ha...
#
#                                       slang_replaced  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so you dont ...
#
#                                contractions_replaced  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate. ...
# 2  not sure why people are so hype about this. th...
# 3  love it! cake in bowl definitely so delicious ...
# 4  the queue always long, tapi laju! so you dont ...
#
#                                       no_punctuation  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate o...
# 2  not sure why people are so hype about this the...
# 3  love it cake in bowl definitely so delicious n...
# 4  the queue always long tapi laju so you dont ha...
#
#                                           no_numbers  \
# 0  i recently visited suka desert and tried a var...
# 1  my review is simple because i love chocolate o...
# 2  not sure why people are so hype about this the...
# 3  love it cake in bowl definitely so delicious n...
# 4  the queue always long tapi laju so you dont ha...
#
#                                   spelling_corrected  \
# 0  i recently visited ska desert and tried a vari...
# 1  my review is simple because i love chocolate o...
# 2  not sure why people are so hype about this the...
# 3  love it cake in bowl definitely so delicious n...
# 4  the queue always long tape lau so you dont hav...
#
#                                         no_stopwords  \
# 0  recently visited ska desert tried variety offe...
# 1  review simple love chocolate course it’s sweet...
# 2  sure people hype sure various dessert cakes ta...
# 3  love cake bowl definitely delicious sweet nice...
# 4  queue always long tape lau dont worry standing...
#
#                                           lemmatized  \
# 0  recently visit ska desert try variety offering...
# 1  review simple love chocolate course it ’ s swe...
# 2  sure people hype sure various dessert cake tas...
# 3  love cake bowl definitely delicious sweet nice...
# 4  queue always long tape lau dont worry stand lo...
#
#                                            tokenized  \
# 0  ['recently', 'visit', 'ska', 'desert', 'try', ...
# 1  ['review', 'simple', 'love', 'chocolate', 'cou...
# 2  ['sure', 'people', 'hype', 'sure', 'various', ...
# 3  ['love', 'cake', 'bowl', 'definitely', 'delici...
# 4  ['queue', 'always', 'long', 'tape', 'lau', 'do...
#
#                                     processed_review
# 0  ['recently', 'visit', 'ska', 'desert', 'try', ...
# 1  ['review', 'simple', 'love', 'chocolate', 'cou...
# 2  ['sure', 'people', 'hype', 'sure', 'various', ...
# 3  ['love', 'cake', 'bowl', 'definitely', 'delici...
# 4  ['queue', 'always', 'long', 'tape', 'lau', 'do...
#
# Missing values per column:
# username                 0
# Past Action              0
# Time                     0
# Review                   0
# lowercase                0
# no_urls                  0
# no_html                  0
# no_emojis                0
# slang_replaced           0
# contractions_replaced    0
# no_punctuation           0
# no_numbers               0
# spelling_corrected       0
# no_stopwords             0
# lemmatized               0
# tokenized                0
# processed_review         0
# dtype: int64
# Visualizations completed.
